# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d90f8d2f-c82b-4011-9bf0-0d8d73fadd71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d90f8d2f-c82b-4011-9bf0-0d8d73fadd71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
pd.read_excel("insurance.xlsx")
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df = pd.read_excel("insurance.xlsx")
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
x = df[['age','sex','bmi','children','smoker','region']]

y = df['expenses']
print("Independant")
print(x.head())
print("Dependent")
print(y.head())
# Out:
# Independant
#    age     sex   bmi  children smoker     region
# 0   19  female  27.9         0    yes  southwest
# 1   18    male  33.8         1     no  southeast
# 2   28    male  33.0         3     no  southeast
# 3   33    male  22.7         0     no  northwest
# 4   32    male  28.9         0     no  northwest
# Dependent
# 0    16884.92
# 1     1725.55
# 2     4449.46
# 3    21984.47
# 4     3866.86
# Name: expenses, dtype: float64

# %%
from sklearn.preprocessing import OneHotEncoder
x_encoaded = pd.get_dummies(x,columns=['sex','smoker','region'],drop_first=True)
print(x_encoaded.head())
# Out:
#    age   bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0     False        True             False
# 1   18  33.8         1      True       False             False
# 2   28  33.0         3      True       False             False
# 3   33  22.7         0      True       False              True
# 4   32  28.9         0      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_encoaded)
print(x_scaled[:5])
# Out:
# [[-1.43876426 -0.4536457  -0.90861367 -1.0105187   1.97058663 -0.56641788
#   -0.61132367  1.76548098]
#  [-1.50996545  0.51418574 -0.07876719  0.98959079 -0.5074631  -0.56641788
#    1.63579466 -0.56641788]
#  [-0.79795355  0.38295436  1.58092576  0.98959079 -0.5074631  -0.56641788
#    1.63579466 -0.56641788]
#  [-0.4419476  -1.30664968 -0.90861367  0.98959079 -0.5074631   1.76548098
#   -0.61132367 -0.56641788]
#  [-0.51314879 -0.28960647 -0.90861367  0.98959079 -0.5074631   1.76548098
#   -0.61132367 -0.56641788]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(
    x_scaled,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1070, 8)
# (268, 8)
# (1070,)
# (268,)

# %%
from sklearn.linear_model import LinearRegression

# Create Linear Regression model
model = LinearRegression()

# Train the model
model.fit(x_train, y_train)

print("Linear Regression Model Trained Successfully!")
# Out:
# Linear Regression Model Trained Successfully!

# %%
y_pred = model.predict(x_test)
print(y_test.head())
print(y_pred[:5])
# Out:
# 764      9095.07
# 887      5272.18
# 890     29330.98
# 1293     9301.89
# 259     33750.29
# Name: expenses, dtype: float64
# [ 8976.76760964  7061.47078348 36861.00837958  9439.16742899
#  26965.82783567]

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test , y_pred)
print(r2)
# Out:
# 0.7835726930039905

# %%
import joblib

# Save the trained model
joblib.dump(model, "insurance_expense_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!
